# %%
# imports and setup
# %matplotlib inline

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

pd.set_option('precision', 2) # number precision for pandas
pd.set_option('display.max_rows', 10)
pd.set_option('display.float_format', '{:20,.2f}'.format) # get rid of scientific notation
plt.style.use('seaborn') # pretty matplotlib plots

# %%
boston = pd.read_csv('/Users/appler/Desktop/Boston.csv', index_col=0)
boston.head(2)
# Out:
#                   crim                   zn                indus  chas  \
# 1                 0.01                18.00                 2.31     0
# 2                 0.03                 0.00                 7.07     0
#
#                    nox                   rm                  age  \
# 1                 0.54                 6.58                65.20
# 2                 0.47                 6.42                78.90
#
#                    dis  rad  tax              ptratio                black  \
# 1                 4.09    1  296                15.30               396.90
# 2                 4.97    2  242                17.80               396.90
#
#                  lstat                 medv
# 1                 4.98                24.00
# 2                 9.14                21.60

# %% [markdown]
# # using scikit-learn

# %%
from sklearn import linear_model

# %%
#ols model with intercept #建立一元线性回归模型
ols_sl = linear_model.LinearRegression(fit_intercept=True)
x_train=boston['lstat'].values.reshape(-1,1)
y_true=boston['medv']
ols_sl.fit(x_train,y_true) #把模型应用于train数据和真实数据是。模型输出数据是y_pred
#summary
ols_sl.coef_,ols_sl.intercept_

# %%
#metrics
from sklearn.metrics import mean_squared_error, explained_variance_score,r2_score
y_pred = ols_sl.predict(boston['lstat'].values.reshape(-1,1))
ols_sl_summary={'R2':r2_score(y_true, y_pred), 'Ex.Var':explained_variance_score(y_true,y_pred),'MSE':mean_squared_error(y_true,y_pred)}

# %%
for k, v in ols_sl_summary.items():
    print(k,":",v)
# Out:
# R2 : 0.5441462975864799
# Ex.Var : 0.5441462975864798
# MSE : 38.48296722989414

# %%
y_pred #是一个矢量
# Out:
# array([29.8225951 , 25.87038979, 30.72514198, 31.76069578, 29.49007782,
#        29.60408375, 22.74472741, 16.36039575,  6.11886372, 18.30799693,
#        15.1253316 , 21.94668596, 19.62856553, 26.70643322, 24.80633451,
#        26.50692285, 28.30251613, 20.61661686, 23.44776393, 23.83728417,
#        14.58380346, 21.41465832, 16.76891698, 15.66685973, 19.06803641,
#        18.86852605, 20.48360995, 18.13698805, 22.39320915, 23.17224962,
#        13.08272548, 22.16519731,  8.22797329, 17.12043524, 15.22983702,
#        25.35736314, 23.71377775, 26.22190805, 24.92984093, 30.44962767,
#        32.67274316, 29.95560201, 29.03405413, 27.48547369, 25.48086955,
#        24.85383698, 21.11064252, 16.69291303,  5.28282029, 19.16304135,
#        21.77567707, 25.59487547, 29.53758029, 26.54492483, 20.49311044,
#        29.98410349, 29.07205611, 30.80114593, 28.03650231, 25.79438584,
#        22.06069188, 20.83512821, 28.16000873, 25.52837202, 26.90594358,
# ...

# %%
#out-of-sample predictions
ols_sl.predict(np.array([5, 10, 15]).reshape(-1, 1))
# Out:
# array([29.80359411, 25.05334734, 20.30310057])

# %% [markdown]
# # Using statsmodels

# %%
# Using statsmodels 使用统计模型中的OLS
import statsmodels.api as sm
# predictor & dependent variable
x_train=boston['lstat']
y_true=boston['medv']
# ols model with intercept added to predictor
ols_sm = sm.OLS(y_true,sm.add_constant(x_train)) #线性回归，有截距

# %%
#fitted model and summary
ols_sm_results = ols_sm.fit()
ols_sm_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     601.6
# Date:                Mon, 07 Sep 2020   Prob (F-statistic):           5.08e-88
# Time:                        16:57:59   Log-Likelihood:                -1641.5
# No. Observations:                 506   AIC:                             3287.
# Df Residuals:                     504   BIC:                             3295.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         34.5538      0.563     61.415      0.000      33.448      35.659
# ...

# %%
#out-of-sample predictions/extrapolation
ols_sm_results.predict(sm.add_constant([5,10,15]))
# Out:
# array([29.80359411, 25.05334734, 20.30310057])

# %%
#prediction intervals
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from collections import OrderedDict

y_pred = ols_sm_results.predict(sm.add_constant(x_train))
prstd,iv_l,iv_u = wls_prediction_std(ols_sm_results)
pred_dict = OrderedDict({
    'x_train':x_train,
    'y_pred':y_pred,
    'y_true':y_true,
    'lwr':iv_l,
    'upr':iv_u,
    'pred_se':prstd
})
pd.DataFrame(pred_dict)
#什么是iv_l, iv_u, prstd?
#lwr: lower boundary 
#upr: upper boundary
# Out:
#                  x_train               y_pred               y_true  \
# 1                   4.98                29.82                24.00
# 2                   9.14                25.87                21.60
# 3                   4.03                30.73                34.70
# 4                   2.94                31.76                33.40
# 5                   5.33                29.49                36.20
# ..                   ...                  ...                  ...
# 502                 9.67                25.37                22.40
# 503                 9.08                25.93                20.60
# 504                 5.64                29.20                23.90
# 505                 6.48                28.40                22.00
# 506                 7.88                27.07                11.90
#
#                      lwr                  upr              pred_se
# 1                  17.58                42.06                 6.23
# ...

# %%
sns.regplot('lstat','medv',data = boston) #回归图：线性回归，并别包括了预测的上限值和下限值。用虚线的图框表示。

# %%
from statsmodels.graphics.regressionplots import *
ols_sm_resid = ols_sm_results.resid #residuals
ols_sm_resid_stud = ols_sm_resid/prstd #studentized residuals

f,axes=plt.subplots(2,2,sharex=False, sharey=False)
f.set_figheight(10)
f.set_figwidth(15)

sns.regplot('lstat','medv',data=boston,ax=axes[0,0],scatter_kws={'alpha':0.5}) #regression plot
sns.residplot(y_pred,'medv',data=boston,ax=axes[0,1],scatter_kws={'alpha':0.5}) #residual plot

#plot_leverage_resid2(ols_sm_results,ax=axes[1,0],color='red') #leverage plot
#custom leverage plot instead of above
from statsmodels.stats.outliers_influence import OLSInfluence
from scipy.stats import zscore
norm_resid = zscore(ols_sm_resid)
leverage = OLSInfluence(ols_sm_results).hat_matrix_diag

axes[1,0].autoscale(enable=True,axis='y',tight=True)
axes[1,0].scatter(norm_resid**2, leverage, alpha=0.5,color='red')

#studentized residual plot
axes[1,1].scatter(y_pred,ols_sm_resid_stud,alpha=0.5,color='magenta')
axes[1,1].axhline(0,ls=':',c='0.2')
axes[1,1].axhline(-3,ls=':',c='0.6')
axes[1,1].axhline(3,ls=':',c='.6')
axes[1,1].set_ylim(-5,5)

x=y_pred[np.logical_or(ols_sm_resid_stud> 3, ols_sm_resid_stud < -3)]
y=ols_sm_resid_stud[np.logical_or(ols_sm_resid_stud > 3, ols_sm_resid_stud < -3)]

for i,x,y in zip(x.index,x,y):
    axes[1,1].annotate(i,xy=(x,y))

# %%
#item with the highest leverage(0-indexed)
leverage.argmax(),leverage.max()
# Out:
# (374, 0.0268651665102835)

# %% [markdown]
# # 3.6.3 multiple linear regression

# %%
#predictors and dependent var 选用2个X
x_train = boston[['lstat','age']]
y_true = boston['medv']

# %%
#ols model with intercept added to the predictor
ols_sm = sm.OLS(y_true,sm.add_constant(x_train))
#fitted model and summary
ols_sm_results = ols_sm.fit()
ols_sm_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     309.0
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):           2.98e-88
# Time:                        06:51:00   Log-Likelihood:                -1637.5
# No. Observations:                 506   AIC:                             3281.
# Df Residuals:                     503   BIC:                             3294.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         33.2228      0.731     45.458      0.000      31.787      34.659
# ...

# %%
import statsmodels.formula.api as smf #R-style formula api
#ols model with intercept
ols_smf=smf.ols(formula='medv~lstat+age',data=boston)

# %%
#fitted model and summary
ols_smf_results = ols_smf.fit()
ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     309.0
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):           2.98e-88
# Time:                        06:53:26   Log-Likelihood:                -1637.5
# No. Observations:                 506   AIC:                             3281.
# Df Residuals:                     503   BIC:                             3294.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     33.2228      0.731     45.458      0.000      31.787      34.659
# ...

# %%
def ols_formula(df,dependent_var, *excluded_cols):
    df_columns=list(df.columns.values)
    df_columns.remove(dependent_var)
    for col in excluded_cols:
        df_columns.remove(col)
    return dependent_var + '~' + '+'.join(df_columns)
#ols model with intercept
ols_smf = smf.ols(formula = ols_formula(boston,'medv'),data=boston)
#fitted model with summary
ols_smf_results=ols_smf.fit()
ols_smf_results.summary()
#这里的t值指的是什么？
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):          6.72e-135
# Time:                        07:14:48   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.4595      5.103      7.144      0.000      26.432      46.487
# ...

# %%
#variance inflation factors
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
import pandas as pd

#don't forget to add constant if the ols model includes intercept
boston_exog = sm.add_constant(boston.drop('medv',axis=1))
#print(boston_exog)
#too fancy for printing results
for i,col in enumerate(boston_exog.columns):
    if col == 'const':
        pass
    elif len(col) > 6:
        print(col,':','{0:.2f}'.format(vif(boston_exog.as_matrix(),i)))
    else:
        print(col,'\t:','{0:.2f}'.format(vif(boston_exog.as_matrix(),i)))
        
#AttributeError: 'DataFrame' object has no attribute 'as_matrix'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-2c1ea43bf9c1> in <module>
#      13         print(col,':','{0:.2f}'.format(vif(boston_exog.as_matrix(),i)))
#      14     else:
# ---> 15         print(col,'\t:','{0:.2f}'.format(vif(boston_exog.as_matrix(),i)))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'as_matrix'

# %%
#ols model with intercept
ols_smf = smf.ols(formula = ols_formula(boston,'medv','age'),data=boston)
#fitted model and summary
ols_smf_results= ols_smf.fit()
ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     117.3
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):          6.08e-136
# Time:                        07:28:51   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3024.
# Df Residuals:                     493   BIC:                             3079.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.4369      5.080      7.172      0.000      26.456      46.418
# ...

# %% [markdown]
# # 3.6.4 Interaction Terms

# %%
#ols model with intercept
ols_smf = smf.ols(formula = 'medv ~ lstat * age',data = boston)
#fitted model and summary
ols_smf_results = ols_smf.fit()
ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.553
# Method:                 Least Squares   F-statistic:                     209.3
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):           4.86e-88
# Time:                        07:33:24   Log-Likelihood:                -1635.0
# No. Observations:                 506   AIC:                             3278.
# Df Residuals:                     502   BIC:                             3295.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.0885      1.470     24.553      0.000      33.201      38.976
# ...

# %% [markdown]
# # 3.6.5 Non-linear Transformations of Predictors

# %%
#ols model with intercept
ols_smf = smf.ols(formula = 'medv~lstat + np.power(lstat,2)',data=boston)

# %%
#fitted model and summary
ols_smf_results = ols_smf.fit()
ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.641
# Model:                            OLS   Adj. R-squared:                  0.639
# Method:                 Least Squares   F-statistic:                     448.5
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):          1.56e-112
# Time:                        07:37:27   Log-Likelihood:                -1581.3
# No. Observations:                 506   AIC:                             3169.
# Df Residuals:                     503   BIC:                             3181.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
# anova of the two models 通过两个模型测试来对比是否一个模型包含了另一个模型
ols_smf = smf.ols(formula = 'medv ~ lstat',data=boston).fit()
ols_smf2 = smf.ols(formula = 'medv ~ lstat + np.power(lstat,2)', data = boston).fit()

sm.stats.anova_lm(ols_smf, ols_smf2)
# Out:
# /Users/appler/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
#               df_resid                  ssr              df_diff  \
# 0               504.00            19,472.38                 0.00
# 1               503.00            15,347.24                 1.00
#
#                ss_diff                    F               Pr(>F)
# 0                  nan                  nan                  nan
# 1             4,125.14               135.20                 0.00

# %%
#记得’alpha‘：0.5要去除掉0.5的String格式，改成number 格式
f, axes = plt.subplots(4,2, sharex = False, sharey = False)
f.set_figheight(20)

sns.regplot('lstat','medv',data=boston,ax=axes[0,0],order=1,line_kws={'color':'grey'},scatter_kws={'alpha':0.5})
sns.regplot('lstat','medv',data=boston,ax=axes[0,1],order=2,line_kws={'color':'grey'},scatter_kws={'alpha':0.5})
sns.regplot('lstat','medv',data=boston,ax=axes[1,0],order=3,line_kws={'color':'grey'},scatter_kws={'alpha':0.5})
sns.regplot('lstat','medv',data=boston,ax=axes[1,1],order=5,line_kws={'color':'grey'},scatter_kws={'alpha':0.5})

sns.residplot('lstat','medv',data=boston,ax=axes[2,0],order=1,line_kws={'color':'grey'},scatter_kws={'alpha':0.5})
sns.residplot('lstat','medv',data=boston,ax=axes[2,1],order=2,line_kws={'color':'grey'},scatter_kws={'alpha':0.5})
sns.residplot('lstat','medv',data=boston,ax=axes[3,0],order=3,line_kws={'color':'grey'},scatter_kws={'alpha':0.5})
sns.residplot('lstat','medv',data=boston,ax=axes[3,1],order=5,line_kws={'color':'grey'},scatter_kws={'alpha':0.5})

# %%
# polynomial ols model with intercept 一元多次方程
# patsy way
ols_smf = smf.ols(formula='medv ~ lstat + I(lstat**2) +I(lstat**3)+I(lstat**4)+I(lstat**5)', data=boston)

# %%
# fitted model and summary
ols_smf_results = ols_smf.fit()
ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     214.2
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):          8.73e-122
# Time:                        07:52:07   Log-Likelihood:                -1550.6
# No. Observations:                 506   AIC:                             3113.
# Df Residuals:                     500   BIC:                             3139.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# polynomial ols model with intercept 通过房间数量的log值来预测medv
ols_smf = smf.ols(formula = 'medv ~ np.log(rm)',data=boston)

# fitted model and summary
ols_smf_results = ols_smf.fit()
ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.435
# Method:                 Least Squares   F-statistic:                     389.3
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):           1.22e-64
# Time:                        07:55:06   Log-Likelihood:                -1695.4
# No. Observations:                 506   AIC:                             3395.
# Df Residuals:                     504   BIC:                             3403.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -76.4878      5.028    -15.213      0.000     -86.366     -66.610
# ...

# %% [markdown]
# # 3.6.6 Qualitative Predictors

# %%
carseats = pd.read_csv('/Users/appler/Desktop/Carseats.csv',index_col=0)
carseats
# Out:
#                    Sales  CompPrice  Income  Advertising  Population  Price  \
# 1                   9.50        138      73           11         276    120
# 2                  11.22        111      48           16         260     83
# 3                  10.06        113      35           10         269     80
# 4                   7.40        117     100            4         466     97
# 5                   4.15        141      64            3         340    128
# ..                   ...        ...     ...          ...         ...    ...
# 396                12.57        138     108           17         203    128
# 397                 6.14        139      23            3          37    120
# 398                 7.41        162      26           12         368    159
# 399                 5.94        100      79            7         284     95
# 400                 9.71        134      37            0          27    120
#
#     ShelveLoc  Age  Education Urban   US
# ...

# %%
# ols model with intercept #为什么Response variable是sales, predictor是ShelveLoc, 这个题目里面有ShelveLoc?
form=ols_formula(carseats, 'Sales','ShelveLoc')+'+Income:Advertising + Price:Age + C(ShelveLoc)'

# %%
ols_smf = smf.ols(formula=form, data = carseats)

# %%
#fitted model and summary
ols_smf_results = ols_smf.fit()
ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     210.0
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):          6.14e-166
# Time:                        08:07:44   Log-Likelihood:                -564.67
# No. Observations:                 400   AIC:                             1157.
# Df Residuals:                     386   BIC:                             1213.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
from patsy.contrasts import Treatment
Treatment(reference = 0).code_without_intercept(list(carseats['ShelveLoc'].unique())).matrix
# Out:
# array([[0., 0.],
#        [1., 0.],
#        [0., 1.]])

# %% [markdown]
# # 3.6.7 Writing Functions
